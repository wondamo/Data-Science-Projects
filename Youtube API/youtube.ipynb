# %%
DEVELOPER_KEY = 'AIzaSyDBEUquA5ZtxwXcgsSXeqHeKUzsmtfVFy0'
api_service = 'youtube'
api_version = 'v3'
credentials = 'atlantean-force-322010-firebase-adminsdk-hk6n2-589edbca88.json'

# %%
import googleapiclient.discovery
import pandas as pd

youtube = googleapiclient.discovery.build(api_service, api_version,developerKey=DEVELOPER_KEY)

def get_channelByCountry(query):
    # request for channel list
    search = youtube.search().list(q = query, type='Channel', order='viewCount', part = "id, snippet", maxResults=100000).execute()
    # extracting the results from search response
    results = search['items']
    res = []

    # empty dictionary to store channel title and Id
    channels = {}
    while 'nextPageToken' in  search.keys():
        # extracting required info from each result object
        res.append(results)
        for result in results:
            if result['id']['kind'] == "youtube#channel":
                channels[result['snippet']['channelTitle']] = result['snippet']['channelId']
        search = youtube.search().list(q = query, type='Channel', order='viewCount', part = "id, snippet", pageToken=search['nextPageToken'], maxResults=10000).execute()
        results = search['items']
    return channels

# %%
chnnels = get_channelByCountry("church")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# c:\Users\Wonder\Data-Science-Projects\Youtube API\youtube.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Wonder/Data-Science-Projects/Youtube%20API/youtube.ipynb#ch0000005?line=0'>1</a> chnnels = get_channelByCountry("church")
#
# c:\Users\Wonder\Data-Science-Projects\Youtube API\youtube.ipynb Cell 2' in get_channelByCountry(query)
#      <a href='vscode-notebook-cell:/c%3A/Users/Wonder/Data-Science-Projects/Youtube%20API/youtube.ipynb#ch0000003?line=18'>19</a>         if result['id']['kind'] == "youtube#channel":
#      <a href='vscode-notebook-cell:/c%3A/Users/Wonder/Data-Science-Projects/Youtube%20API/youtube.ipynb#ch0000003?line=19'>20</a>             channels[result['snippet']['channelTitle']] = result['snippet']['channelId']
# ...

# %%
youtube.get_channelDetails(youtube.get_channelByCountry('ministry', 'ZW'))
# Out:
# {'soulfood ministry': {'viewCount': '39050',
#   'subscriberCount': '670',
#   'hiddenSubscriberCount': False,
#   'videoCount': '11'},
#  'Ministry of Health and Child Care': {'viewCount': '21061',
#   'subscriberCount': '226',
#   'hiddenSubscriberCount': False,
#   'videoCount': '52'},
#  'Kalli Ministry': {'viewCount': '117304',
#   'subscriberCount': '574',
#   'hiddenSubscriberCount': False,
#   'videoCount': '75'},
#  'Kairos Prison Ministry International': {'viewCount': '89099',
#   'subscriberCount': '1120',
#   'hiddenSubscriberCount': False,
#   'videoCount': '92'},
#  'Office of the Prime Minister - Ethiopia': {'viewCount': '1784874',
#   'hiddenSubscriberCount': True,
#   'videoCount': '435'},
#  'Alfa Omega Ministry': {'viewCount': '315073',
#   'subscriberCount': '3390',
#   'hiddenSubscriberCount': False,
#   'videoCount': '490'},
#  'Jesus Youth Kuwait - English Music Ministry': {'viewCount': '26539',
#   'subscriberCount': '303',
#   'hiddenSubscriberCount': False,
# ...

# %%
df.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Southampton United Church to Church Boy Videos
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   viewCount        50 non-null     object
#  1   subscriberCount  49 non-null     object
#  2   videoCount       50 non-null     object
# dtypes: object(3)
# memory usage: 3.6+ KB
